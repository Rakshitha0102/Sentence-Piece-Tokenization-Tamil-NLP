# %% [markdown]
# NAME:RAKSHITHA M
#
# REG NO:2022510016
#
#
# ---

# %% [markdown]
# # **Sentence piece tokenization**
#
# ---

# %% [markdown]
# # **About the dataset**
# Source:Extracted from various Tamil Wikipedia articles.
#
# Content:Contains diverse topics (e.g., culture, science, history).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **import libraries**

# %%
from pathlib import Path
import sentencepiece as spm
import pandas as pd

# %% [markdown]
# # **load data**

# %%
gz_file = '/content/drive/My Drive/filtered_data.csv.gz'

lang_data = pd.read_csv(gz_file, compression='gzip', encoding='utf-8')

lang_data = lang_data.replace({'\ufffd': ''}, regex=True)

print(lang_data.head())
# Out:
#    Unnamed: 0     id                                        url  \
# 0           0  48482  https://ta.wikipedia.org/wiki?curid=48482
# 1           1  48485  https://ta.wikipedia.org/wiki?curid=48485
# 2           2  48486  https://ta.wikipedia.org/wiki?curid=48486
# 3           3  48492  https://ta.wikipedia.org/wiki?curid=48492
# 4           4  48493  https://ta.wikipedia.org/wiki?curid=48493
#
#                 title                                               text
# 0        தென் துருவம்  தென் துருவம் தென் முனை தென் துருவம் என்பது புவ...
# 1    ஆர்க்டிக் வட்டம்  ஆர்க்டிக் வட்டம் ஆர்க்டிக் வட்டம் என்பது ஐந்து...
# 2      நாஞ்சில் நாடன்  நாஞ்சில் நாடன் நாஞ்சில் நாடன் பிறப்பு திசம்பர்...
# 3            டிக்கோயா  டிக்கோயா டிக்கோயா இலங்கையின் மத்திய மாகாணத்தின...
# 4  நள்ளிரவுச் சூரியன்  நள்ளிரவுச் சூரியன் நள்ளிரவுச் சூரியன் அல்லது த...

# %%
lang_data.head()
# Out:
#    Unnamed: 0     id                                        url  \
# 0           0  48482  https://ta.wikipedia.org/wiki?curid=48482
# 1           1  48485  https://ta.wikipedia.org/wiki?curid=48485
# 2           2  48486  https://ta.wikipedia.org/wiki?curid=48486
# 3           3  48492  https://ta.wikipedia.org/wiki?curid=48492
# 4           4  48493  https://ta.wikipedia.org/wiki?curid=48493
#
#                 title                                               text
# 0        தென் துருவம்  தென் துருவம் தென் முனை தென் துருவம் என்பது புவ...
# 1    ஆர்க்டிக் வட்டம்  ஆர்க்டிக் வட்டம் ஆர்க்டிக் வட்டம் என்பது ஐந்து...
# 2      நாஞ்சில் நாடன்  நாஞ்சில் நாடன் நாஞ்சில் நாடன் பிறப்பு திசம்பர்...
# 3            டிக்கோயா  டிக்கோயா டிக்கோயா இலங்கையின் மத்திய மாகாணத்தின...
# 4  நள்ளிரவுச் சூரியன்  நள்ளிரவுச் சூரியன் நள்ளிரவுச் சூரியன் அல்லது த...

# %% [markdown]
# # **Preprocessing**

# %%
lang_data.drop('Unnamed: 0', axis=1, inplace=True)
print(" Removed 'Unnamed: 0' column.")
# Out:
#  Removed 'Unnamed: 0' column.

# %%
lang_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133412 entries, 0 to 133411
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      133412 non-null  int64
#  1   url     133412 non-null  object
#  2   title   133412 non-null  object
#  3   text    133412 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 4.1+ MB

# %%
lang_data.shape
# Out:
# (133412, 4)

# %%
OUTPUT_DIR = Path('/content/working')
TEXTS_DIR = OUTPUT_DIR/'texts'
TOK_DIR = OUTPUT_DIR/'tokenizer'

TOK_DIR.mkdir(parents=True, exist_ok=True)
TEXTS_DIR.mkdir(parents=True, exist_ok=True)

# %%
print(f" Duplicates: {lang_data.duplicated().sum()}")

lang_data.drop_duplicates(inplace=True)

print(f" Missing values:\n{lang_data.isnull().sum()}")

lang_data.dropna(inplace=True)
print(" Removed duplicates and missing values.")
# Out:
#  Duplicates: 0
#  Missing values:
# id       0
# url      0
# title    0
# text     0
# dtype: int64
#  Removed duplicates and missing values.

# %%
lang_data.shape
# Out:
# (133412, 4)

# %% [markdown]
# ## **Saving dataset rows as text files**

# %%
for t in lang_data.itertuples():
    file_name = Path(TEXTS_DIR/f'text_{t.Index}.txt')
    file_name.touch()
    with file_name.open('w') as f:
        f.write(t.text)

# %%
len([t for t in TEXTS_DIR.iterdir()]), lang_data.shape[0]
# Out:
# (133412, 133412)

# %% [markdown]
# ## **Displaying Generated File Names**

# %%
files = ','.join([str(t) for t in TEXTS_DIR.iterdir()])
files[:100]
# Out:
# '/content/working/texts/text_90856.txt,/content/working/texts/text_48726.txt,/content/working/texts/t'

# %% [markdown]
# ## **Training SentencePiece Tokenizer with Different Vocabulary Sizes**

# %%
import sentencepiece as spm
for v in 8000, 16000, 20000, 30000:
    api_str = f"""--input={files} --vocab_size={v} --model_type=unigram --character_coverage=0.9995 --model_prefix={str(TOK_DIR)}/tok_{v}_size --max_sentence_length=20000"""
    print("Training with vocab set as:", v)
    spm.SentencePieceTrainer.train(api_str)
# Out:
# Training with vocab set as: 8000
# Training with vocab set as: 16000
# Training with vocab set as: 20000
# Training with vocab set as: 30000

# %% [markdown]
# This code trains a SentencePiece tokenizer with different vocabulary sizes (8000, 16000, 20000, 30000).
#
# Iteration: It loops over the four vocabulary sizes.
#
# API String: Constructs the training parameters, including:
#
# --input={files} → Uses the previously created text files as input.
#
# --vocab_size={v} → Sets the vocabulary size dynamically for each iteration.
#
# --model_type=unigram → Specifies the unigram language model.
#
# --character_coverage=0.9995 → Covers 99.95% of the characters for accuracy.
#
# --model_prefix={str(TOK_DIR)}/tok_{v}_size → Sets the output model prefix path.
#
# --max_sentence_length=20000 → Defines the maximum sentence length for processing.
#
# Training:
#
# spm.SentencePieceTrainer.train(api_str) → Trains the tokenizer with the specified parameters.
#
# Output:
#
# Prints the current vocabulary size being used for training.

# %% [markdown]
# ## **Listing All Files in a Directory Recursively**

# %%
import os
for dirname, _, filenames in os.walk('/content'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/working/texts/text_99795.txt
# /content/working/texts/text_79455.txt
# /content/working/texts/text_102033.txt
# /content/working/texts/text_63848.txt
# /content/working/texts/text_5578.txt
# /content/working/texts/text_128021.txt
# /content/working/texts/text_9534.txt
# /content/working/texts/text_116445.txt
# /content/working/texts/text_28547.txt
# /content/working/texts/text_84413.txt
# /content/working/texts/text_9273.txt
# /content/working/texts/text_22349.txt
# /content/working/texts/text_90194.txt
# /content/working/texts/text_716.txt
# /content/working/texts/text_68053.txt
# /content/working/texts/text_14947.txt
# /content/working/texts/text_26107.txt
# /content/working/texts/text_3459.txt
# /content/working/texts/text_85289.txt
# /content/working/texts/text_72382.txt
# /content/working/texts/text_57193.txt
# /content/working/texts/text_80015.txt
# /content/working/texts/text_84856.txt
# /content/working/texts/text_17351.txt
# /content/working/texts/text_46258.txt
# /content/working/texts/text_88845.txt
# /content/working/texts/text_108099.txt
# /content/working/texts/text_48212.txt
# /content/working/texts/text_130531.txt
# /content/working/texts/text_123698.txt
# /content/working/texts/text_57217.txt
# /content/working/texts/text_105646.txt
# /content/working/texts/text_44905.txt
# /content/working/texts/text_124748.txt
# /content/working/texts/text_34309.txt
# /content/working/texts/text_11092.txt
# /content/working/texts/text_48365.txt
# /content/working/texts/text_62116.txt
# /content/working/texts/text_23402.txt
# /content/working/texts/text_63526.txt
# /content/working/texts/text_66233.txt
# /content/working/texts/text_13279.txt
# /content/working/texts/text_49316.txt
# /content/working/texts/text_58323.txt
# /content/working/texts/text_29099.txt
# /content/working/texts/text_62330.txt
# /content/working/texts/text_99480.txt
# /content/working/texts/text_52739.txt
# /content/working/texts/text_89199.txt
# /content/working/texts/text_46718.txt
# /content/working/texts/text_132383.txt
# /content/working/texts/text_123216.txt
# /content/working/texts/text_121828.txt
# /content/working/texts/text_10277.txt
# /content/working/texts/text_89920.txt
# /content/working/texts/text_112972.txt
# /content/working/texts/text_118953.txt
# /content/working/texts/text_85357.txt
# /content/working/texts/text_99543.txt
# /content/working/texts/text_10607.txt
# /content/working/texts/text_124987.txt
# /content/working/texts/text_104778.txt
# /content/working/texts/text_129560.txt
# /content/working/texts/text_28119.txt
# /content/working/texts/text_41313.txt
# /content/working/texts/text_9731.txt
# /content/working/texts/text_61188.txt
# /content/working/texts/text_18963.txt
# /content/working/texts/text_65801.txt
# /content/working/texts/text_20860.txt
# /content/working/texts/text_70416.txt
# /content/working/texts/text_110937.txt
# /content/working/texts/text_88638.txt
# /content/working/texts/text_77814.txt
# /content/working/texts/text_66529.txt
# /content/working/texts/text_96103.txt
# /content/working/texts/text_30626.txt
# /content/working/texts/text_77505.txt
# /content/working/texts/text_76206.txt
# /content/working/texts/text_127022.txt
# /content/working/texts/text_82823.txt
# /content/working/texts/text_27516.txt
# /content/working/texts/text_48937.txt
# /content/working/texts/text_52818.txt
# /content/working/texts/text_16688.txt
# /content/working/texts/text_55071.txt
# /content/working/texts/text_125340.txt
# /content/working/texts/text_60549.txt
# /content/working/texts/text_110806.txt
# /content/working/texts/text_126452.txt
# /content/working/texts/text_99315.txt
# /content/working/texts/text_53209.txt
# /content/working/texts/text_68415.txt
# /content/working/texts/text_44631.txt
# /content/working/texts/text_13011.txt
# /content/working/texts/text_69299.txt
# /content/working/texts/text_46905.txt
# /content/working/texts/text_95935.txt
# /content/working/texts/text_10375.txt
# /content/working/texts/text_45927.txt
# /content/working/texts/text_21629.txt
# /content/working/texts/text_78175.txt
# /content/working/texts/text_34973.txt
# /content/working/texts/text_25148.txt
# /content/working/texts/text_16801.txt
# /content/working/texts/text_97931.txt
# /content/working/texts/text_96834.txt
# /content/working/texts/text_116334.txt
# /content/working/texts/text_54832.txt
# /content/working/texts/text_39578.txt
# /content/working/texts/text_97472.txt
# /content/working/texts/text_23687.txt
# /content/working/texts/text_68592.txt
# /content/working/texts/text_19082.txt
# /content/working/texts/text_123426.txt
# /content/working/texts/text_18229.txt
# /content/working/texts/text_11696.txt
# /content/working/texts/text_49871.txt
# /content/working/texts/text_5055.txt
# /content/working/texts/text_81268.txt
# /content/working/texts/text_72125.txt
# /content/working/texts/text_40624.txt
# /content/working/texts/text_66927.txt
# /content/working/texts/text_80836.txt
# /content/working/texts/text_41633.txt
# /content/working/texts/text_22674.txt
# /content/working/texts/text_93008.txt
# /content/working/texts/text_17693.txt
# /content/working/texts/text_123045.txt
# /content/working/texts/text_63335.txt
# /content/working/texts/text_35029.txt
# /content/working/texts/text_111509.txt
# /content/working/texts/text_124749.txt
# /content/working/texts/text_40580.txt
# /content/working/texts/text_118902.txt
# /content/working/texts/text_90709.txt
# /content/working/texts/text_123928.txt
# /content/working/texts/text_49195.txt
# /content/working/texts/text_122142.txt
# /content/working/texts/text_108456.txt
# /content/working/texts/text_39609.txt
# /content/working/texts/text_5325.txt
# /content/working/texts/text_119894.txt
# /content/working/texts/text_78157.txt
# /content/working/texts/text_128597.txt
# /content/working/texts/text_122099.txt
# /content/working/texts/text_79275.txt
# /content/working/texts/text_114468.txt
# /content/working/texts/text_36178.txt
# /content/working/texts/text_105036.txt
# /content/working/texts/text_91088.txt
# /content/working/texts/text_27240.txt
# /content/working/texts/text_132997.txt
# /content/working/texts/text_130294.txt
# /content/working/texts/text_35147.txt
# /content/working/texts/text_56666.txt
# /content/working/texts/text_44552.txt
# /content/working/texts/text_3291.txt
# /content/working/texts/text_49982.txt
# /content/working/texts/text_125449.txt
# /content/working/texts/text_10982.txt
# /content/working/texts/text_18933.txt
# /content/working/texts/text_20495.txt
# /content/working/texts/text_56952.txt
# /content/working/texts/text_27580.txt
# /content/working/texts/text_16327.txt
# /content/working/texts/text_24966.txt
# /content/working/texts/text_99655.txt
# /content/working/texts/text_101163.txt
# /content/working/texts/text_89024.txt
# /content/working/texts/text_53282.txt
# /content/working/texts/text_20145.txt
# /content/working/texts/text_69497.txt
# /content/working/texts/text_74652.txt
# /content/working/texts/text_100146.txt
# /content/working/texts/text_28314.txt
# /content/working/texts/text_70564.txt
# /content/working/texts/text_44395.txt
# /content/working/texts/text_88977.txt
# /content/working/texts/text_31902.txt
# /content/working/texts/text_75252.txt
# /content/working/texts/text_21402.txt
# /content/working/texts/text_9444.txt
# /content/working/texts/text_37913.txt
# /content/working/texts/text_123034.txt
# /content/working/texts/text_108147.txt
# /content/working/texts/text_2641.txt
# /content/working/texts/text_79491.txt
# /content/working/texts/text_2470.txt
# /content/working/texts/text_55666.txt
# /content/working/texts/text_121948.txt
# /content/working/texts/text_102062.txt
# /content/working/texts/text_93366.txt
# /content/working/texts/text_68442.txt
# /content/working/texts/text_100920.txt
# /content/working/texts/text_9241.txt
# /content/working/texts/text_97796.txt
# /content/working/texts/text_18081.txt
# /content/working/texts/text_121909.txt
# /content/working/texts/text_88255.txt
# /content/working/texts/text_103465.txt
# /content/working/texts/text_51330.txt
# /content/working/texts/text_78595.txt
# /content/working/texts/text_89974.txt
# /content/working/texts/text_94474.txt
# /content/working/texts/text_19507.txt
# /content/working/texts/text_6873.txt
# /content/working/texts/text_52795.txt
# /content/working/texts/text_24738.txt
# /content/working/texts/text_3331.txt
# /content/working/texts/text_100230.txt
# /content/working/texts/text_117616.txt
# /content/working/texts/text_42069.txt
# /content/working/texts/text_9717.txt
# /content/working/texts/text_47611.txt
# /content/working/texts/text_68997.txt
# /content/working/texts/text_112175.txt
# /content/working/texts/text_43817.txt
# /content/working/texts/text_119601.txt
# /content/working/texts/text_113254.txt
# /content/working/texts/text_112370.txt
# /content/working/texts/text_130146.txt
# /content/working/texts/text_50491.txt
# /content/working/texts/text_68817.txt
# /content/working/texts/text_41422.txt
# /content/working/texts/text_11337.txt
# /content/working/texts/text_66306.txt
# /content/working/texts/text_109517.txt
# /content/working/texts/text_124979.txt
# /content/working/texts/text_102986.txt
# /content/working/texts/text_5575.txt
# /content/working/texts/text_29987.txt
# /content/working/texts/text_55331.txt
# /content/working/texts/text_87573.txt
# /content/working/texts/text_71473.txt
# /content/working/texts/text_9016.txt
# /content/working/texts/text_133317.txt
# /content/working/texts/text_73154.txt
# /content/working/texts/text_26507.txt
# /content/working/texts/text_113638.txt
# /content/working/texts/text_109719.txt
# /content/working/texts/text_46732.txt
# /content/working/texts/text_32699.txt
# /content/working/texts/text_105352.txt
# /content/working/texts/text_61364.txt
# /content/working/texts/text_117731.txt
# /content/working/texts/text_52499.txt
# /content/working/texts/text_82192.txt
# /content/working/texts/text_77149.txt
# /content/working/texts/text_25769.txt
# /content/working/texts/text_68180.txt
# /content/working/texts/text_3896.txt
# /content/working/texts/text_33157.txt
# /content/working/texts/text_67510.txt
# /content/working/texts/text_25197.txt
# /content/working/texts/text_98247.txt
# /content/working/texts/text_63026.txt
# /content/working/texts/text_66190.txt
# /content/working/texts/text_13729.txt
# /content/working/texts/text_119425.txt
# /content/working/texts/text_1890.txt
# /content/working/texts/text_11672.txt
# /content/working/texts/text_131783.txt
# /content/working/texts/text_126489.txt
# /content/working/texts/text_64065.txt
# /content/working/texts/text_103047.txt
# /content/working/texts/text_13307.txt
# /content/working/texts/text_119027.txt
# /content/working/texts/text_69501.txt
# /content/working/texts/text_61167.txt
# /content/working/texts/text_113508.txt
# /content/working/texts/text_75303.txt
# /content/working/texts/text_118257.txt
# /content/working/texts/text_59500.txt
# /content/working/texts/text_102204.txt
# /content/working/texts/text_47237.txt
# /content/working/texts/text_27852.txt
# /content/working/texts/text_83186.txt
# /content/working/texts/text_127122.txt
# /content/working/texts/text_77835.txt
# /content/working/texts/text_89989.txt
# /content/working/texts/text_50724.txt
# /content/working/texts/text_106102.txt
# /content/working/texts/text_62693.txt
# /content/working/texts/text_89309.txt
# /content/working/texts/text_104792.txt
# /content/working/texts/text_67799.txt
# /content/working/texts/text_58559.txt
# /content/working/texts/text_82991.txt
# /content/working/texts/text_70939.txt
# /content/working/texts/text_23566.txt
# /content/working/texts/text_17869.txt
# /content/working/texts/text_12415.txt
# /content/working/texts/text_18251.txt
# /content/working/texts/text_55259.txt
# /content/working/texts/text_127214.txt
# /content/working/texts/text_1435.txt
# /content/working/texts/text_70865.txt
# /content/working/texts/text_62778.txt
# /content/working/texts/text_32155.txt
# /content/working/texts/text_115507.txt
# /content/working/texts/text_18234.txt
# /content/working/texts/text_72407.txt
# /content/working/texts/text_5342.txt
# /content/working/texts/text_18199.txt
# /content/working/texts/text_65947.txt
# /content/working/texts/text_24791.txt
# /content/working/texts/text_40828.txt
# /content/working/texts/text_15213.txt
# /content/working/texts/text_52959.txt
# /content/working/texts/text_62064.txt
# /content/working/texts/text_94466.txt
# /content/working/texts/text_118378.txt
# /content/working/texts/text_40586.txt
# /content/working/texts/text_54204.txt
# /content/working/texts/text_130491.txt
# /content/working/texts/text_63021.txt
# /content/working/texts/text_89243.txt
# /content/working/texts/text_15360.txt
# /content/working/texts/text_46199.txt
# /content/working/texts/text_84715.txt
# /content/working/texts/text_15816.txt
# /content/working/texts/text_88366.txt
# /content/working/texts/text_128526.txt
# /content/working/texts/text_29223.txt
# /content/working/texts/text_51382.txt
# /content/working/texts/text_28881.txt
# /content/working/texts/text_110174.txt
# /content/working/texts/text_120107.txt
# /content/working/texts/text_83383.txt
# /content/working/texts/text_22827.txt
# /content/working/texts/text_109771.txt
# /content/working/texts/text_116391.txt
# /content/working/texts/text_35497.txt
# /content/working/texts/text_35817.txt
# /content/working/texts/text_106929.txt
# /content/working/texts/text_128669.txt
# /content/working/texts/text_32636.txt
# /content/working/texts/text_71587.txt
# /content/working/texts/text_110590.txt
# /content/working/texts/text_39874.txt
# /content/working/texts/text_81973.txt
# /content/working/texts/text_62287.txt
# /content/working/texts/text_56695.txt
# /content/working/texts/text_29088.txt
# /content/working/texts/text_104619.txt
# /content/working/texts/text_63514.txt
# /content/working/texts/text_83614.txt
# /content/working/texts/text_41077.txt
# /content/working/texts/text_55139.txt
# /content/working/texts/text_109136.txt
# /content/working/texts/text_61942.txt
# /content/working/texts/text_50884.txt
# /content/working/texts/text_37435.txt
# /content/working/texts/text_18707.txt
# /content/working/texts/text_22722.txt
# /content/working/texts/text_104615.txt
# /content/working/texts/text_111569.txt
# /content/working/texts/text_94742.txt
# /content/working/texts/text_3892.txt
# /content/working/texts/text_58132.txt
# /content/working/texts/text_66959.txt
# /content/working/texts/text_114871.txt
# /content/working/texts/text_75806.txt
# /content/working/texts/text_51217.txt
# /content/working/texts/text_37138.txt
# /content/working/texts/text_34458.txt
# /content/working/texts/text_101722.txt
# /content/working/texts/text_85325.txt
# /content/working/texts/text_80865.txt
# /content/working/texts/text_24971.txt
# /content/working/texts/text_129195.txt
# /content/working/texts/text_32529.txt
# /content/working/texts/text_64789.txt
# /content/working/texts/text_71958.txt
# /content/working/texts/text_56548.txt
# /content/working/texts/text_1171.txt
# /content/working/texts/text_53480.txt
# /content/working/texts/text_102753.txt
# /content/working/texts/text_86940.txt
# /content/working/texts/text_22346.txt
# /content/working/texts/text_32668.txt
# /content/working/texts/text_22980.txt
# /content/working/texts/text_55930.txt
# /content/working/texts/text_43238.txt
# /content/working/texts/text_16383.txt
# /content/working/texts/text_31579.txt
# /content/working/texts/text_30289.txt
# /content/working/texts/text_42498.txt
# /content/working/texts/text_128364.txt
# /content/working/texts/text_112296.txt
# /content/working/texts/text_29617.txt
# /content/working/texts/text_24934.txt
# /content/working/texts/text_49068.txt
# /content/working/texts/text_43344.txt
# /content/working/texts/text_28684.txt
# /content/working/texts/text_12700.txt
# /content/working/texts/text_53932.txt
# /content/working/texts/text_129423.txt
# /content/working/texts/text_71267.txt
# /content/working/texts/text_69425.txt
# /content/working/texts/text_102895.txt
# /content/working/texts/text_116026.txt
# /content/working/texts/text_65435.txt
# /content/working/texts/text_131656.txt
# /content/working/texts/text_60470.txt
# /content/working/texts/text_130706.txt
# /content/working/texts/text_68132.txt
# /content/working/texts/text_37156.txt
# /content/working/texts/text_67266.txt
# /content/working/texts/text_59668.txt
# /content/working/texts/text_2115.txt
# /content/working/texts/text_7633.txt
# /content/working/texts/text_29991.txt
# /content/working/texts/text_51901.txt
# /content/working/texts/text_80356.txt
# /content/working/texts/text_109531.txt
# /content/working/texts/text_95439.txt
# /content/working/texts/text_38287.txt
# /content/working/texts/text_83254.txt
# /content/working/texts/text_3075.txt
# /content/working/texts/text_1588.txt
# /content/working/texts/text_124110.txt
# /content/working/texts/text_113702.txt
# /content/working/texts/text_17557.txt
# /content/working/texts/text_80561.txt
# /content/working/texts/text_46015.txt
# /content/working/texts/text_43304.txt
# /content/working/texts/text_33995.txt
# /content/working/texts/text_37050.txt
# /content/working/texts/text_105963.txt
# /content/working/texts/text_39247.txt
# /content/working/texts/text_79272.txt
# /content/working/texts/text_88589.txt
# /content/working/texts/text_77779.txt
# /content/working/texts/text_44841.txt
# /content/working/texts/text_582.txt
# /content/working/texts/text_17413.txt
# /content/working/texts/text_49915.txt
# /content/working/texts/text_105406.txt
# /content/working/texts/text_50990.txt
# /content/working/texts/text_105861.txt
# /content/working/texts/text_83652.txt
# /content/working/texts/text_44291.txt
# /content/working/texts/text_80840.txt
# /content/working/texts/text_110389.txt
# /content/working/texts/text_84627.txt
# /content/working/texts/text_26268.txt
# /content/working/texts/text_107666.txt
# /content/working/texts/text_80159.txt
# /content/working/texts/text_21098.txt
# /content/working/texts/text_69455.txt
# /content/working/texts/text_106746.txt
# /content/working/texts/text_35653.txt
# /content/working/texts/text_130930.txt
# /content/working/texts/text_34121.txt
# /content/working/texts/text_34576.txt
# /content/working/texts/text_22208.txt
# /content/working/texts/text_98470.txt
# /content/working/texts/text_31904.txt
# /content/working/texts/text_119046.txt
# /content/working/texts/text_80254.txt
# /content/working/texts/text_51567.txt
# /content/working/texts/text_120422.txt
# /content/working/texts/text_21767.txt
# /content/working/texts/text_59899.txt
# /content/working/texts/text_62273.txt
# /content/working/texts/text_20812.txt
# /content/working/texts/text_108942.txt
# /content/working/texts/text_123968.txt
# /content/working/texts/text_69401.txt
# /content/working/texts/text_85478.txt
# /content/working/texts/text_43760.txt
# /content/working/texts/text_30032.txt
# /content/working/texts/text_115321.txt
# /content/working/texts/text_110257.txt
# /content/working/texts/text_9123.txt
# /content/working/texts/text_81150.txt
# /content/working/texts/text_77782.txt
# /content/working/texts/text_66316.txt
# /content/working/texts/text_20548.txt
# /content/working/texts/text_133047.txt
# /content/working/texts/text_128311.txt
# /content/working/texts/text_16485.txt
# /content/working/texts/text_10088.txt
# /content/working/texts/text_35148.txt
# /content/working/texts/text_9416.txt
# /content/working/texts/text_57275.txt
# /content/working/texts/text_110010.txt
# /content/working/texts/text_45540.txt
# /content/working/texts/text_6084.txt
# /content/working/texts/text_15788.txt
# /content/working/texts/text_128982.txt
# /content/working/texts/text_91062.txt
# /content/working/texts/text_79084.txt
# /content/working/texts/text_2877.txt
# /content/working/texts/text_127151.txt
# /content/working/texts/text_6773.txt
# /content/working/texts/text_68139.txt
# /content/working/texts/text_66867.txt
# /content/working/texts/text_107211.txt
# /content/working/texts/text_50566.txt
# /content/working/texts/text_50966.txt
# /content/working/texts/text_67713.txt
# /content/working/texts/text_106954.txt
# /content/working/texts/text_31972.txt
# /content/working/texts/text_22374.txt
# /content/working/texts/text_119042.txt
# /content/working/texts/text_33487.txt
# /content/working/texts/text_11358.txt
# /content/working/texts/text_124127.txt
# /content/working/texts/text_114281.txt
# /content/working/texts/text_44772.txt
# /content/working/texts/text_35486.txt
# /content/working/texts/text_85226.txt
# /content/working/texts/text_1688.txt
# /content/working/texts/text_111438.txt
# /content/working/texts/text_38436.txt
# /content/working/texts/text_125829.txt
# /content/working/texts/text_89119.txt
# /content/working/texts/text_44183.txt
# /content/working/texts/text_6719.txt
# /content/working/texts/text_31142.txt
# /content/working/texts/text_14191.txt
# /content/working/texts/text_40621.txt
# /content/working/texts/text_66617.txt
# /content/working/texts/text_62016.txt
# /content/working/texts/text_128123.txt
# /content/working/texts/text_42402.txt
# /content/working/texts/text_7265.txt
# /content/working/texts/text_105312.txt
# /content/working/texts/text_2556.txt
# /content/working/texts/text_63741.txt
# /content/working/texts/text_111715.txt
# /content/working/texts/text_103297.txt
# /content/working/texts/text_132112.txt
# /content/working/texts/text_103490.txt
# /content/working/texts/text_106236.txt
# /content/working/texts/text_96414.txt
# /content/working/texts/text_100170.txt
# /content/working/texts/text_52746.txt
# /content/working/texts/text_32613.txt
# /content/working/texts/text_28124.txt
# /content/working/texts/text_130663.txt
# /content/working/texts/text_113676.txt
# /content/working/texts/text_79534.txt
# /content/working/texts/text_32808.txt
# /content/working/texts/text_92867.txt
# /content/working/texts/text_19893.txt
# /content/working/texts/text_123599.txt
# /content/working/texts/text_109234.txt
# /content/working/texts/text_25492.txt
# /content/working/texts/text_102491.txt
# /content/working/texts/text_41762.txt
# /content/working/texts/text_94791.txt
# /content/working/texts/text_33238.txt
# /content/working/texts/text_66799.txt
# /content/working/texts/text_70255.txt
# /content/working/texts/text_78912.txt
# /content/working/texts/text_53367.txt
# /content/working/texts/text_125725.txt
# /content/working/texts/text_55121.txt
# /content/working/texts/text_9190.txt
# /content/working/texts/text_4668.txt
# /content/working/texts/text_65150.txt
# /content/working/texts/text_111828.txt
# /content/working/texts/text_41335.txt
# /content/working/texts/text_66296.txt
# /content/working/texts/text_107100.txt
# /content/working/texts/text_87414.txt
# /content/working/texts/text_48903.txt
# /content/working/texts/text_19039.txt
# /content/working/texts/text_61638.txt
# /content/working/texts/text_19769.txt
# /content/working/texts/text_4044.txt
# /content/working/texts/text_64527.txt
# /content/working/texts/text_64457.txt
# /content/working/texts/text_14114.txt
# /content/working/texts/text_12459.txt
# /content/working/texts/text_95260.txt
# /content/working/texts/text_31694.txt
# /content/working/texts/text_87299.txt
# /content/working/texts/text_39355.txt
# /content/working/texts/text_73670.txt
# /content/working/texts/text_54176.txt
# /content/working/texts/text_41116.txt
# /content/working/texts/text_60266.txt
# /content/working/texts/text_105742.txt
# /content/working/texts/text_133279.txt
# /content/working/texts/text_35209.txt
# /content/working/texts/text_73595.txt
# /content/working/texts/text_58085.txt
# /content/working/texts/text_118820.txt
# /content/working/texts/text_60167.txt
# /content/working/texts/text_45183.txt
# /content/working/texts/text_65048.txt
# /content/working/texts/text_122455.txt
# /content/working/texts/text_62241.txt
# /content/working/texts/text_64603.txt
# /content/working/texts/text_60327.txt
# /content/working/texts/text_85228.txt
# /content/working/texts/text_76391.txt
# /content/working/texts/text_86287.txt
# /content/working/texts/text_10991.txt
# /content/working/texts/text_12368.txt
# /content/working/texts/text_85123.txt
# /content/working/texts/text_62950.txt
# /content/working/texts/text_94049.txt
# /content/working/texts/text_4845.txt
# /content/working/texts/text_127216.txt
# /content/working/texts/text_113782.txt
# /content/working/texts/text_95675.txt
# /content/working/texts/text_121168.txt
# /content/working/texts/text_16720.txt
# /content/working/texts/text_76431.txt
# /content/working/texts/text_17274.txt
# /content/working/texts/text_112666.txt
# /content/working/texts/text_117233.txt
# /content/working/texts/text_66929.txt
# /content/working/texts/text_49469.txt
# /content/working/texts/text_122369.txt
# /content/working/texts/text_45105.txt
# /content/working/texts/text_2722.txt
# /content/working/texts/text_119136.txt
# /content/working/texts/text_55919.txt
# /content/working/texts/text_51731.txt
# /content/working/texts/text_121392.txt
# /content/working/texts/text_98620.txt
# /content/working/texts/text_130689.txt
# /content/working/texts/text_58920.txt
# /content/working/texts/text_63759.txt
# /content/working/texts/text_10166.txt
# /content/working/texts/text_46123.txt
# /content/working/texts/text_83277.txt
# /content/working/texts/text_10806.txt
# /content/working/texts/text_74091.txt
# /content/working/texts/text_58140.txt
# /content/working/texts/text_131307.txt
# /content/working/texts/text_92833.txt
# /content/working/texts/text_13074.txt
# /content/working/texts/text_103545.txt
# /content/working/texts/text_18376.txt
# /content/working/texts/text_126942.txt
# /content/working/texts/text_29644.txt
# /content/working/texts/text_82339.txt
# /content/working/texts/text_93159.txt
# /content/working/texts/text_101519.txt
# /content/working/texts/text_101435.txt
# /content/working/texts/text_120466.txt
# /content/working/texts/text_9932.txt
# /content/working/texts/text_33728.txt
# /content/working/texts/text_63933.txt
# /content/working/texts/text_61847.txt
# /content/working/texts/text_60853.txt
# /content/working/texts/text_109181.txt
# /content/working/texts/text_75290.txt
# /content/working/texts/text_115897.txt
# /content/working/texts/text_33124.txt
# /content/working/texts/text_23323.txt
# /content/working/texts/text_45641.txt
# /content/working/texts/text_97470.txt
# /content/working/texts/text_4433.txt
# /content/working/texts/text_128317.txt
# /content/working/texts/text_22112.txt
# /content/working/texts/text_85453.txt
# /content/working/texts/text_93601.txt
# /content/working/texts/text_37853.txt
# /content/working/texts/text_88979.txt
# /content/working/texts/text_110498.txt
# /content/working/texts/text_65904.txt
# /content/working/texts/text_98635.txt
# /content/working/texts/text_129847.txt
# /content/working/texts/text_100030.txt
# /content/working/texts/text_69846.txt
# /content/working/texts/text_63161.txt
# /content/working/texts/text_51745.txt
# /content/working/texts/text_29121.txt
# /content/working/texts/text_88693.txt
# /content/working/texts/text_71461.txt
# /content/working/texts/text_32019.txt
# /content/working/texts/text_50221.txt
# /content/working/texts/text_88774.txt
# /content/working/texts/text_22174.txt
# /content/working/texts/text_105257.txt
# /content/working/texts/text_18479.txt
# /content/working/texts/text_111829.txt
# /content/working/texts/text_62059.txt
# /content/working/texts/text_65227.txt
# /content/working/texts/text_60787.txt
# /content/working/texts/text_62915.txt
# /content/working/texts/text_66831.txt
# /content/working/texts/text_19144.txt
# /content/working/texts/text_37026.txt
# /content/working/texts/text_7140.txt
# /content/working/texts/text_64046.txt
# /content/working/texts/text_83585.txt
# /content/working/texts/text_61523.txt
# /content/working/texts/text_2153.txt
# /content/working/texts/text_122666.txt
# /content/working/texts/text_79156.txt
# /content/working/texts/text_127740.txt
# /content/working/texts/text_55157.txt
# /content/working/texts/text_109699.txt
# /content/working/texts/text_92614.txt
# /content/working/texts/text_105319.txt
# /content/working/texts/text_27763.txt
# /content/working/texts/text_115635.txt
# /content/working/texts/text_31423.txt
# /content/working/texts/text_112624.txt
# /content/working/texts/text_42924.txt
# /content/working/texts/text_6391.txt
# /content/working/texts/text_66815.txt
# /content/working/texts/text_34096.txt
# /content/working/texts/text_70650.txt
# /content/working/texts/text_75262.txt
# /content/working/texts/text_8414.txt
# /content/working/texts/text_126436.txt
# /content/working/texts/text_36395.txt
# /content/working/texts/text_103601.txt
# /content/working/texts/text_2360.txt
# /content/working/texts/text_87263.txt
# /content/working/texts/text_81780.txt
# /content/working/texts/text_122655.txt
# /content/working/texts/text_41881.txt
# /content/working/texts/text_84037.txt
# /content/working/texts/text_92459.txt
# /content/working/texts/text_79400.txt
# /content/working/texts/text_127580.txt
# /content/working/texts/text_31023.txt
# /content/working/texts/text_71802.txt
# /content/working/texts/text_63449.txt
# /content/working/texts/text_111576.txt
# /content/working/texts/text_54601.txt
# /content/working/texts/text_34683.txt
# /content/working/texts/text_20332.txt
# /content/working/texts/text_45568.txt
# /content/working/texts/text_70088.txt
# /content/working/texts/text_10193.txt
# /content/working/texts/text_23933.txt
# /content/working/texts/text_29069.txt
# /content/working/texts/text_13431.txt
# /content/working/texts/text_81924.txt
# /content/working/texts/text_916.txt
# /content/working/texts/text_5774.txt
# /content/working/texts/text_113706.txt
# /content/working/texts/text_92905.txt
# /content/working/texts/text_24289.txt
# /content/working/texts/text_115215.txt
# /content/working/texts/text_1603.txt
# /content/working/texts/text_117505.txt
# /content/working/texts/text_31386.txt
# /content/working/texts/text_47001.txt
# /content/working/texts/text_123002.txt
# /content/working/texts/text_129289.txt
# /content/working/texts/text_109937.txt
# /content/working/texts/text_32914.txt
# /content/working/texts/text_67188.txt
# /content/working/texts/text_131545.txt
# /content/working/texts/text_68935.txt
# /content/working/texts/text_5483.txt
# /content/working/texts/text_108889.txt
# /content/working/texts/text_79902.txt
# /content/working/texts/text_110546.txt
# /content/working/texts/text_67789.txt
# /content/working/texts/text_100532.txt
# /content/working/texts/text_64480.txt
# /content/working/texts/text_119533.txt
# /content/working/texts/text_97974.txt
# /content/working/texts/text_89168.txt
# /content/working/texts/text_13549.txt
# /content/working/texts/text_97498.txt
# /content/working/texts/text_52199.txt
# /content/working/texts/text_115454.txt
# /content/working/texts/text_12737.txt
# /content/working/texts/text_121612.txt
# /content/working/texts/text_46536.txt
# /content/working/texts/text_31234.txt
# /content/working/texts/text_73803.txt
# /content/working/texts/text_23856.txt
# /content/working/texts/text_126855.txt
# /content/working/texts/text_52246.txt
# /content/working/texts/text_5816.txt
# /content/working/texts/text_29167.txt
# /content/working/texts/text_31846.txt
# /content/working/texts/text_24103.txt
# /content/working/texts/text_103383.txt
# /content/working/texts/text_111271.txt
# /content/working/texts/text_7557.txt
# /content/working/texts/text_2423.txt
# /content/working/texts/text_61576.txt
# /content/working/texts/text_63511.txt
# /content/working/texts/text_116894.txt
# /content/working/texts/text_65384.txt
# /content/working/texts/text_25621.txt
# /content/working/texts/text_106556.txt
# /content/working/texts/text_82914.txt
# /content/working/texts/text_108327.txt
# /content/working/texts/text_9881.txt
# /content/working/texts/text_53930.txt
# /content/working/texts/text_10387.txt
# /content/working/texts/text_87696.txt
# /content/working/texts/text_80269.txt
# /content/working/texts/text_50595.txt
# /content/working/texts/text_84307.txt
# /content/working/texts/text_132587.txt
# /content/working/texts/text_48296.txt
# /content/working/texts/text_109712.txt
# /content/working/texts/text_111874.txt
# /content/working/texts/text_103574.txt
# /content/working/texts/text_120172.txt
# /content/working/texts/text_89902.txt
# /content/working/texts/text_6842.txt
# /content/working/texts/text_102933.txt
# /content/working/texts/text_128136.txt
# /content/working/texts/text_37956.txt
# /content/working/texts/text_76506.txt
# /content/working/texts/text_100671.txt
# /content/working/texts/text_7044.txt
# /content/working/texts/text_79336.txt
# /content/working/texts/text_33280.txt
# /content/working/texts/text_89949.txt
# /content/working/texts/text_116165.txt
# /content/working/texts/text_69212.txt
# /content/working/texts/text_19143.txt
# /content/working/texts/text_22366.txt
# /content/working/texts/text_70669.txt
# /content/working/texts/text_81734.txt
# /content/working/texts/text_20170.txt
# /content/working/texts/text_51363.txt
# /content/working/texts/text_10059.txt
# /content/working/texts/text_98350.txt
# /content/working/texts/text_57131.txt
# /content/working/texts/text_31289.txt
# /content/working/texts/text_90439.txt
# /content/working/texts/text_60078.txt
# /content/working/texts/text_112487.txt
# /content/working/texts/text_10139.txt
# /content/working/texts/text_61199.txt
# /content/working/texts/text_111006.txt
# /content/working/texts/text_92944.txt
# /content/working/texts/text_116317.txt
# /content/working/texts/text_3317.txt
# /content/working/texts/text_65179.txt
# /content/working/texts/text_27490.txt
# /content/working/texts/text_59344.txt
# /content/working/texts/text_118024.txt
# /content/working/texts/text_34760.txt
# /content/working/texts/text_34873.txt
# /content/working/texts/text_70729.txt
# /content/working/texts/text_49816.txt
# /content/working/texts/text_37464.txt
# /content/working/texts/text_103447.txt
# /content/working/texts/text_57744.txt
# /content/working/texts/text_68742.txt
# /content/working/texts/text_10130.txt
# /content/working/texts/text_36399.txt
# /content/working/texts/text_116542.txt
# /content/working/texts/text_65273.txt
# /content/working/texts/text_1549.txt
# /content/working/texts/text_115675.txt
# /content/working/texts/text_33814.txt
# /content/working/texts/text_8905.txt
# /content/working/texts/text_32455.txt
# /content/working/texts/text_15837.txt
# /content/working/texts/text_96163.txt
# /content/working/texts/text_117312.txt
# /content/working/texts/text_101697.txt
# /content/working/texts/text_89244.txt
# /content/working/texts/text_95593.txt
# /content/working/texts/text_71766.txt
# /content/working/texts/text_104996.txt
# /content/working/texts/text_62305.txt
# /content/working/texts/text_112685.txt
# /content/working/texts/text_73878.txt
# /content/working/texts/text_37102.txt
# /content/working/texts/text_95266.txt
# /content/working/texts/text_77135.txt
# /content/working/texts/text_19585.txt
# /content/working/texts/text_85369.txt
# /content/working/texts/text_10068.txt
# /content/working/texts/text_4849.txt
# /content/working/texts/text_104428.txt
# /content/working/texts/text_44015.txt
# /content/working/texts/text_50250.txt
# /content/working/texts/text_72960.txt
# /content/working/texts/text_36942.txt
# /content/working/texts/text_44594.txt
# /content/working/texts/text_29481.txt
# /content/working/texts/text_109322.txt
# /content/working/texts/text_70107.txt
# /content/working/texts/text_63076.txt
# /content/working/texts/text_25400.txt
# /content/working/texts/text_78328.txt
# /content/working/texts/text_25482.txt
# /content/working/texts/text_18704.txt
# /content/working/texts/text_53013.txt
# /content/working/texts/text_40439.txt
# /content/working/texts/text_12136.txt
# /content/working/texts/text_23385.txt
# /content/working/texts/text_112167.txt
# /content/working/texts/text_75430.txt
# /content/working/texts/text_6730.txt
# /content/working/texts/text_104249.txt
# /content/working/texts/text_98561.txt
# /content/working/texts/text_75255.txt
# /content/working/texts/text_125098.txt
# /content/working/texts/text_87239.txt
# /content/working/texts/text_86649.txt
# /content/working/texts/text_12695.txt
# /content/working/texts/text_117788.txt
# /content/working/texts/text_77166.txt
# /content/working/texts/text_112152.txt
# /content/working/texts/text_89691.txt
# /content/working/texts/text_82500.txt
# /content/working/texts/text_66550.txt
# /content/working/texts/text_111954.txt
# /content/working/texts/text_113741.txt
# /content/working/texts/text_102498.txt
# /content/working/texts/text_56604.txt
# /content/working/texts/text_97901.txt
# /content/working/texts/text_64496.txt
# /content/working/texts/text_59955.txt
# /content/working/texts/text_27341.txt
# /content/working/texts/text_7028.txt
# /content/working/texts/text_87893.txt
# /content/working/texts/text_24357.txt
# /content/working/texts/text_11003.txt
# /content/working/texts/text_75973.txt
# /content/working/texts/text_22645.txt
# /content/working/texts/text_67684.txt
# /content/working/texts/text_103913.txt
# /content/working/texts/text_37633.txt
# /content/working/texts/text_81189.txt
# /content/working/texts/text_7761.txt
# /content/working/texts/text_26721.txt
# /content/working/texts/text_66185.txt
# /content/working/texts/text_73581.txt
# /content/working/texts/text_91387.txt
# /content/working/texts/text_88427.txt
# /content/working/texts/text_26990.txt
# /content/working/texts/text_66801.txt
# /content/working/texts/text_6070.txt
# /content/working/texts/text_54519.txt
# /content/working/texts/text_109688.txt
# /content/working/texts/text_51468.txt
# /content/working/texts/text_124686.txt
# /content/working/texts/text_297.txt
# /content/working/texts/text_32374.txt
# /content/working/texts/text_132048.txt
# /content/working/texts/text_41495.txt
# /content/working/texts/text_98197.txt
# /content/working/texts/text_3785.txt
# /content/working/texts/text_112911.txt
# /content/working/texts/text_16029.txt
# /content/working/texts/text_8956.txt
# /content/working/texts/text_21699.txt
# /content/working/texts/text_79888.txt
# /content/working/texts/text_61955.txt
# /content/working/texts/text_110224.txt
# /content/working/texts/text_16592.txt
# /content/working/texts/text_53430.txt
# /content/working/texts/text_68813.txt
# /content/working/texts/text_58014.txt
# /content/working/texts/text_83230.txt
# /content/working/texts/text_8498.txt
# /content/working/texts/text_3684.txt
# /content/working/texts/text_33137.txt
# /content/working/texts/text_119274.txt
# /content/working/texts/text_59338.txt
# /content/working/texts/text_86359.txt
# /content/working/texts/text_4553.txt
# /content/working/texts/text_38809.txt
# /content/working/texts/text_70616.txt
# /content/working/texts/text_111099.txt
# /content/working/texts/text_19015.txt
# /content/working/texts/text_13104.txt
# /content/working/texts/text_103208.txt
# /content/working/texts/text_106809.txt
# /content/working/texts/text_41.txt
# /content/working/texts/text_59791.txt
# /content/working/texts/text_55713.txt
# /content/working/texts/text_84793.txt
# /content/working/texts/text_51875.txt
# /content/working/texts/text_123282.txt
# /content/working/texts/text_113286.txt
# /content/working/texts/text_17493.txt
# /content/working/texts/text_91635.txt
# /content/working/texts/text_106973.txt
# /content/working/texts/text_77163.txt
# /content/working/texts/text_128227.txt
# /content/working/texts/text_90809.txt
# /content/working/texts/text_4650.txt
# /content/working/texts/text_76311.txt
# /content/working/texts/text_109884.txt
# /content/working/texts/text_26638.txt
# /content/working/texts/text_105144.txt
# /content/working/texts/text_52174.txt
# /content/working/texts/text_67167.txt
# /content/working/texts/text_6922.txt
# /content/working/texts/text_76272.txt
# /content/working/texts/text_29920.txt
# /content/working/texts/text_40366.txt
# /content/working/texts/text_125496.txt
# /content/working/texts/text_130914.txt
# /content/working/texts/text_52849.txt
# /content/working/texts/text_44099.txt
# /content/working/texts/text_94443.txt
# /content/working/texts/text_68641.txt
# /content/working/texts/text_83355.txt
# /content/working/texts/text_115736.txt
# /content/working/texts/text_85061.txt
# /content/working/texts/text_24475.txt
# /content/working/texts/text_29348.txt
# /content/working/texts/text_91722.txt
# /content/working/texts/text_78904.txt
# /content/working/texts/text_107917.txt
# /content/working/texts/text_42044.txt
# /content/working/texts/text_64375.txt
# /content/working/texts/text_100523.txt
# /content/working/texts/text_87806.txt
# /content/working/texts/text_90265.txt
# /content/working/texts/text_30562.txt
# /content/working/texts/text_85323.txt
# /content/working/texts/text_109242.txt
# /content/working/texts/text_38065.txt
# /content/working/texts/text_132393.txt
# /content/working/texts/text_110646.txt
# /content/working/texts/text_9051.txt
# /content/working/texts/text_34002.txt
# /content/working/texts/text_91012.txt
# /content/working/texts/text_53695.txt
# /content/working/texts/text_26647.txt
# /content/working/texts/text_66371.txt
# /content/working/texts/text_31144.txt
# /content/working/texts/text_26363.txt
# /content/working/texts/text_70859.txt
# /content/working/texts/text_3113.txt
# /content/working/texts/text_66629.txt
# /content/working/texts/text_75923.txt
# /content/working/texts/text_50265.txt
# /content/working/texts/text_98323.txt
# /content/working/texts/text_12747.txt
# /content/working/texts/text_131368.txt
# /content/working/texts/text_107417.txt
# /content/working/texts/text_115464.txt
# /content/working/texts/text_64281.txt
# /content/working/texts/text_99379.txt
# /content/working/texts/text_17990.txt
# /content/working/texts/text_56532.txt
# /content/working/texts/text_100935.txt
# /content/working/texts/text_28596.txt
# /content/working/texts/text_45647.txt
# /content/working/texts/text_111681.txt
# /content/working/texts/text_50390.txt
# /content/working/texts/text_83811.txt
# /content/working/texts/text_51181.txt
# /content/working/texts/text_45270.txt
# /content/working/texts/text_16686.txt
# /content/working/texts/text_584.txt
# /content/working/texts/text_92421.txt
# /content/working/texts/text_2042.txt
# /content/working/texts/text_69413.txt
# /content/working/texts/text_75771.txt
# /content/working/texts/text_77270.txt
# /content/working/texts/text_123694.txt
# /content/working/texts/text_100356.txt
# /content/working/texts/text_70304.txt
# /content/working/texts/text_54872.txt
# /content/working/texts/text_49807.txt
# /content/working/texts/text_105021.txt
# /content/working/texts/text_16998.txt
# /content/working/texts/text_45108.txt
# /content/working/texts/text_6687.txt
# /content/working/texts/text_113094.txt
# /content/working/texts/text_4127.txt
# /content/working/texts/text_27271.txt
# /content/working/texts/text_1483.txt
# /content/working/texts/text_1748.txt
# /content/working/texts/text_63001.txt
# /content/working/texts/text_103707.txt
# /content/working/texts/text_43603.txt
# /content/working/texts/text_3390.txt
# /content/working/texts/text_64182.txt
# /content/working/texts/text_27312.txt
# /content/working/texts/text_96357.txt
# /content/working/texts/text_90154.txt
# /content/working/texts/text_73734.txt
# /content/working/texts/text_765.txt
# /content/working/texts/text_73452.txt
# /content/working/texts/text_107678.txt
# /content/working/texts/text_79022.txt
# /content/working/texts/text_94720.txt
# /content/working/texts/text_109609.txt
# /content/working/texts/text_74119.txt
# /content/working/texts/text_110584.txt
# /content/working/texts/text_8894.txt
# /content/working/texts/text_8899.txt
# /content/working/texts/text_51840.txt
# /content/working/texts/text_86656.txt
# /content/working/texts/text_71328.txt
# /content/working/texts/text_97447.txt
# /content/working/texts/text_76289.txt
# /content/working/texts/text_29524.txt
# /content/working/texts/text_49859.txt
# /content/working/texts/text_27461.txt
# /content/working/texts/text_106576.txt
# /content/working/texts/text_131042.txt
# /content/working/texts/text_14724.txt
# /content/working/texts/text_53653.txt
# /content/working/texts/text_27631.txt
# /content/working/texts/text_94500.txt
# /content/working/texts/text_12243.txt
# /content/working/texts/text_118376.txt
# /content/working/texts/text_8361.txt
# /content/working/texts/text_14538.txt
# /content/working/texts/text_111936.txt
# /content/working/texts/text_23732.txt
# /content/working/texts/text_15904.txt
# /content/working/texts/text_49813.txt
# /content/working/texts/text_124632.txt
# /content/working/texts/text_61732.txt
# /content/working/texts/text_61035.txt
# /content/working/texts/text_106156.txt
# /content/working/texts/text_130823.txt
# /content/working/texts/text_30054.txt
# /content/working/texts/text_115756.txt
# /content/working/texts/text_125952.txt
# /content/working/texts/text_43305.txt
# /content/working/texts/text_16228.txt
# /content/working/texts/text_66857.txt
# /content/working/texts/text_97999.txt
# /content/working/texts/text_121079.txt
# /content/working/texts/text_104225.txt
# /content/working/texts/text_9604.txt
# /content/working/texts/text_40320.txt
# /content/working/texts/text_39383.txt
# /content/working/texts/text_93443.txt
# /content/working/texts/text_129610.txt
# /content/working/texts/text_65235.txt
# /content/working/texts/text_113655.txt
# /content/working/texts/text_35410.txt
# /content/working/texts/text_97981.txt
# /content/working/texts/text_81230.txt
# /content/working/texts/text_10572.txt
# /content/working/texts/text_97531.txt
# /content/working/texts/text_40566.txt
# /content/working/texts/text_120997.txt
# /content/working/texts/text_38541.txt
# /content/working/texts/text_76831.txt
# /content/working/texts/text_104961.txt
# /content/working/texts/text_94353.txt
# /content/working/texts/text_110684.txt
# /content/working/texts/text_40281.txt
# /content/working/texts/text_121194.txt
# /content/working/texts/text_50948.txt
# /content/working/texts/text_53908.txt
# /content/working/texts/text_926.txt
# /content/working/texts/text_18943.txt
# /content/working/texts/text_108513.txt
# /content/working/texts/text_51028.txt
# /content/working/texts/text_132669.txt
# /content/working/texts/text_98560.txt
# /content/working/texts/text_27282.txt
# /content/working/texts/text_41300.txt
# /content/working/texts/text_95833.txt
# /content/working/texts/text_64505.txt
# /content/working/texts/text_17238.txt
# /content/working/texts/text_36361.txt
# /content/working/texts/text_71005.txt
# /content/working/texts/text_31302.txt
# /content/working/texts/text_13223.txt
# /content/working/texts/text_119642.txt
# /content/working/texts/text_126004.txt
# /content/working/texts/text_111580.txt
# /content/working/texts/text_7023.txt
# /content/working/texts/text_94254.txt
# /content/working/texts/text_84135.txt
# /content/working/texts/text_70575.txt
# /content/working/texts/text_110986.txt
# /content/working/texts/text_116272.txt
# /content/working/texts/text_12951.txt
# /content/working/texts/text_54494.txt
# /content/working/texts/text_98968.txt
# /content/working/texts/text_17145.txt
# /content/working/texts/text_9687.txt
# /content/working/texts/text_65985.txt
# /content/working/texts/text_52466.txt
# /content/working/texts/text_118304.txt
# /content/working/texts/text_76635.txt
# /content/working/texts/text_74140.txt
# /content/working/texts/text_47957.txt
# /content/working/texts/text_75220.txt
# /content/working/texts/text_40516.txt
# /content/working/texts/text_16758.txt
# /content/working/texts/text_120087.txt
# /content/working/texts/text_2064.txt
# /content/working/texts/text_121525.txt
# /content/working/texts/text_91079.txt
# /content/working/texts/text_5469.txt
# /content/working/texts/text_129901.txt
# /content/working/texts/text_55410.txt
# /content/working/texts/text_118916.txt
# /content/working/texts/text_13202.txt
# /content/working/texts/text_112468.txt
# /content/working/texts/text_45862.txt
# /content/working/texts/text_43252.txt
# /content/working/texts/text_93246.txt
# /content/working/texts/text_38155.txt
# /content/working/texts/text_117370.txt
# /content/working/texts/text_23217.txt
# /content/working/texts/text_72292.txt
# /content/working/texts/text_69382.txt
# /content/working/texts/text_93333.txt
# /content/working/texts/text_123943.txt
# /content/working/texts/text_118524.txt
# /content/working/texts/text_28135.txt
# /content/working/texts/text_52692.txt
# /content/working/texts/text_83394.txt
# /content/working/texts/text_52765.txt
# /content/working/texts/text_27957.txt
# /content/working/texts/text_66592.txt
# /content/working/texts/text_51496.txt
# /content/working/texts/text_85861.txt
# /content/working/texts/text_73294.txt
# /content/working/texts/text_56433.txt
# /content/working/texts/text_104467.txt
# /content/working/texts/text_2139.txt
# /content/working/texts/text_44248.txt
# /content/working/texts/text_39999.txt
# /content/working/texts/text_114764.txt
# /content/working/texts/text_67802.txt
# /content/working/texts/text_122483.txt
# /content/working/texts/text_55365.txt
# /content/working/texts/text_81065.txt
# /content/working/texts/text_82856.txt
# /content/working/texts/text_24175.txt
# /content/working/texts/text_667.txt
# /content/working/texts/text_128262.txt
# /content/working/texts/text_124410.txt
# /content/working/texts/text_124689.txt
# /content/working/texts/text_53122.txt
# /content/working/texts/text_79955.txt
# /content/working/texts/text_87467.txt
# /content/working/texts/text_28175.txt
# /content/working/texts/text_51311.txt
# /content/working/texts/text_108050.txt
# /content/working/texts/text_42634.txt
# /content/working/texts/text_12592.txt
# /content/working/texts/text_40562.txt
# /content/working/texts/text_102188.txt
# /content/working/texts/text_101638.txt
# /content/working/texts/text_53698.txt
# /content/working/texts/text_81672.txt
# /content/working/texts/text_78503.txt
# /content/working/texts/text_24113.txt
# /content/working/texts/text_51360.txt
# ...
# /content/working/texts/text_66312.txt
# /content/working/texts/text_20384.txt
# /content/working/texts/text_65711.txt
# /content/working/texts/text_9879.txt
# /content/working/texts/text_82946.txt
# /content/working/texts/text_78115.txt
# /content/working/texts/text_119887.txt
# /content/working/texts/text_25466.txt
# /content/working/texts/text_10165.txt
# /content/working/texts/text_121462.txt
# /content/working/texts/text_108177.txt
# /content/working/texts/text_37864.txt
# /content/working/texts/text_46563.txt
# /content/working/texts/text_5631.txt
# /content/working/texts/text_59789.txt
# /content/working/texts/text_31460.txt
# /content/working/texts/text_98417.txt
# /content/working/texts/text_106092.txt
# /content/working/texts/text_61276.txt
# /content/working/texts/text_126621.txt
# /content/working/texts/text_72151.txt
# /content/working/texts/text_129874.txt
# /content/working/texts/text_77182.txt
# /content/working/texts/text_45267.txt
# /content/working/texts/text_75516.txt
# /content/working/texts/text_98823.txt
# /content/working/texts/text_38152.txt
# /content/working/texts/text_67616.txt
# /content/working/texts/text_30020.txt
# /content/working/texts/text_87551.txt
# /content/working/texts/text_92174.txt
# /content/working/texts/text_107757.txt
# /content/working/texts/text_92653.txt
# /content/working/texts/text_84010.txt
# /content/working/texts/text_128440.txt
# /content/working/texts/text_113458.txt
# /content/working/texts/text_122568.txt
# /content/working/texts/text_106178.txt
# /content/working/texts/text_40414.txt
# /content/working/texts/text_38546.txt
# /content/working/texts/text_112157.txt
# /content/working/texts/text_33529.txt
# /content/working/texts/text_24385.txt
# /content/working/texts/text_62200.txt
# /content/working/texts/text_93286.txt
# /content/working/texts/text_132944.txt
# /content/working/texts/text_120413.txt
# /content/working/texts/text_5308.txt
# /content/working/texts/text_85299.txt
# /content/working/texts/text_87899.txt
# /content/working/texts/text_125591.txt
# /content/working/texts/text_124396.txt
# /content/working/texts/text_62980.txt
# /content/working/texts/text_123397.txt
# /content/working/texts/text_38083.txt
# /content/working/texts/text_118120.txt
# /content/working/texts/text_56062.txt
# /content/working/texts/text_18671.txt
# /content/working/texts/text_86802.txt
# /content/working/texts/text_129621.txt
# /content/working/texts/text_93007.txt
# /content/working/texts/text_13454.txt
# /content/working/texts/text_64340.txt
# /content/working/texts/text_14581.txt
# /content/working/texts/text_101520.txt
# /content/working/texts/text_9424.txt
# /content/working/texts/text_22342.txt
# /content/working/texts/text_98023.txt
# /content/working/texts/text_99912.txt
# /content/working/texts/text_29702.txt
# /content/working/texts/text_21394.txt
# /content/working/texts/text_73223.txt
# /content/working/texts/text_76784.txt
# /content/working/texts/text_92296.txt
# /content/working/texts/text_31622.txt
# /content/working/texts/text_130210.txt
# /content/working/texts/text_114980.txt
# /content/working/texts/text_44006.txt
# /content/working/texts/text_72644.txt
# /content/working/texts/text_130337.txt
# /content/working/texts/text_133147.txt
# /content/working/texts/text_98364.txt
# /content/working/texts/text_13071.txt
# /content/working/texts/text_93309.txt
# /content/working/texts/text_25047.txt
# /content/working/texts/text_122377.txt
# /content/working/texts/text_41119.txt
# /content/working/texts/text_97077.txt
# /content/working/texts/text_105960.txt
# /content/working/texts/text_39674.txt
# /content/working/texts/text_16266.txt
# /content/working/texts/text_121273.txt
# /content/working/texts/text_94102.txt
# /content/working/texts/text_5488.txt
# /content/working/texts/text_113869.txt
# /content/working/texts/text_98384.txt
# /content/working/texts/text_7960.txt
# /content/working/texts/text_85206.txt
# /content/working/texts/text_8923.txt
# /content/working/texts/text_101304.txt
# /content/working/texts/text_115701.txt
# /content/working/texts/text_58442.txt
# /content/working/texts/text_20663.txt
# /content/working/texts/text_80955.txt
# /content/working/texts/text_25129.txt
# /content/working/texts/text_102068.txt
# /content/working/texts/text_103946.txt
# /content/working/texts/text_100708.txt
# /content/working/texts/text_119911.txt
# /content/working/texts/text_96581.txt
# /content/working/texts/text_62926.txt
# /content/working/texts/text_110839.txt
# /content/working/texts/text_18711.txt
# /content/working/texts/text_32210.txt
# /content/working/texts/text_29739.txt
# /content/working/texts/text_89463.txt
# /content/working/texts/text_103993.txt
# /content/working/texts/text_125991.txt
# /content/working/texts/text_8497.txt
# /content/working/texts/text_750.txt
# /content/working/texts/text_74627.txt
# /content/working/texts/text_106808.txt
# /content/working/texts/text_2351.txt
# /content/working/texts/text_84286.txt
# /content/working/texts/text_116299.txt
# /content/working/texts/text_6193.txt
# /content/working/texts/text_32078.txt
# /content/working/texts/text_89714.txt
# /content/working/texts/text_59912.txt
# /content/working/texts/text_104521.txt
# /content/working/texts/text_2654.txt
# /content/working/texts/text_5147.txt
# /content/working/texts/text_81057.txt
# /content/working/texts/text_127118.txt
# /content/working/texts/text_30080.txt
# /content/working/texts/text_98989.txt
# /content/working/texts/text_131657.txt
# /content/working/texts/text_15028.txt
# /content/working/texts/text_95495.txt
# /content/working/texts/text_98141.txt
# /content/working/texts/text_30683.txt
# /content/working/texts/text_56158.txt
# /content/working/texts/text_127526.txt
# /content/working/texts/text_89594.txt
# /content/working/texts/text_53805.txt
# /content/working/texts/text_61462.txt
# /content/working/texts/text_118484.txt
# /content/working/texts/text_97723.txt
# /content/working/texts/text_34062.txt
# /content/working/texts/text_83748.txt
# /content/working/texts/text_100297.txt
# /content/working/texts/text_53210.txt
# /content/working/texts/text_120014.txt
# /content/working/texts/text_83528.txt
# /content/working/texts/text_32695.txt
# /content/working/texts/text_54286.txt
# /content/working/texts/text_81751.txt
# /content/working/texts/text_73435.txt
# /content/working/texts/text_52024.txt
# /content/working/texts/text_14786.txt
# /content/working/texts/text_126588.txt
# /content/working/texts/text_119267.txt
# /content/working/texts/text_93294.txt
# /content/working/texts/text_41908.txt
# /content/working/texts/text_65492.txt
# /content/working/texts/text_89957.txt
# /content/working/texts/text_66294.txt
# /content/working/texts/text_39824.txt
# /content/working/texts/text_13847.txt
# /content/working/texts/text_49189.txt
# /content/working/texts/text_119278.txt
# /content/working/texts/text_79517.txt
# /content/working/texts/text_118155.txt
# /content/working/texts/text_839.txt
# /content/working/texts/text_64173.txt
# /content/working/texts/text_67424.txt
# /content/working/texts/text_70357.txt
# /content/working/texts/text_132552.txt
# /content/working/texts/text_109829.txt
# /content/working/texts/text_30072.txt
# /content/working/texts/text_38071.txt
# /content/working/texts/text_75242.txt
# /content/working/texts/text_129374.txt
# /content/working/texts/text_29011.txt
# /content/working/texts/text_57798.txt
# /content/working/texts/text_129778.txt
# /content/working/texts/text_32634.txt
# /content/working/texts/text_77918.txt
# /content/working/texts/text_102788.txt
# /content/working/texts/text_23870.txt
# /content/working/texts/text_115605.txt
# /content/working/texts/text_8260.txt
# /content/working/texts/text_40353.txt
# /content/working/texts/text_74740.txt
# /content/working/texts/text_42732.txt
# /content/working/texts/text_61258.txt
# /content/working/texts/text_49297.txt
# /content/working/texts/text_123099.txt
# /content/working/texts/text_107531.txt
# /content/working/texts/text_35705.txt
# /content/working/texts/text_85186.txt
# /content/working/texts/text_126325.txt
# /content/working/texts/text_101762.txt
# /content/working/texts/text_60426.txt
# /content/working/texts/text_123316.txt
# /content/working/texts/text_68375.txt
# /content/working/texts/text_105184.txt
# /content/working/texts/text_94649.txt
# /content/working/texts/text_101984.txt
# /content/working/texts/text_109571.txt
# /content/working/texts/text_43427.txt
# /content/working/texts/text_64414.txt
# /content/working/texts/text_47895.txt
# /content/working/texts/text_27589.txt
# /content/working/texts/text_111881.txt
# /content/working/texts/text_37904.txt
# /content/working/texts/text_51752.txt
# /content/working/texts/text_81737.txt
# /content/working/texts/text_30265.txt
# /content/working/texts/text_116543.txt
# /content/working/texts/text_37749.txt
# /content/working/texts/text_54493.txt
# /content/working/texts/text_74824.txt
# /content/working/texts/text_2628.txt
# /content/working/texts/text_47925.txt
# /content/working/texts/text_83351.txt
# /content/working/texts/text_92021.txt
# /content/working/texts/text_124780.txt
# /content/working/texts/text_19150.txt
# /content/working/texts/text_42792.txt
# /content/working/texts/text_95193.txt
# /content/working/texts/text_130535.txt
# /content/working/texts/text_105133.txt
# /content/working/texts/text_25247.txt
# /content/working/texts/text_55408.txt
# /content/working/texts/text_91276.txt
# /content/working/texts/text_118763.txt
# /content/working/texts/text_94645.txt
# /content/working/texts/text_15777.txt
# /content/working/texts/text_109977.txt
# /content/working/texts/text_97432.txt
# /content/working/texts/text_32840.txt
# /content/working/texts/text_66126.txt
# /content/working/texts/text_68673.txt
# /content/working/texts/text_44350.txt
# /content/working/texts/text_89338.txt
# /content/working/texts/text_54800.txt
# /content/working/texts/text_50626.txt
# /content/working/texts/text_111738.txt
# /content/working/texts/text_107592.txt
# /content/working/texts/text_132010.txt
# /content/working/texts/text_6192.txt
# /content/working/texts/text_74579.txt
# /content/working/texts/text_90973.txt
# /content/working/texts/text_111302.txt
# /content/working/texts/text_28893.txt
# /content/working/texts/text_105894.txt
# /content/working/texts/text_115490.txt
# /content/working/texts/text_96963.txt
# /content/working/texts/text_105330.txt
# /content/working/texts/text_86400.txt
# /content/working/texts/text_109140.txt
# /content/working/texts/text_27367.txt
# /content/working/texts/text_87710.txt
# /content/working/texts/text_16360.txt
# /content/working/texts/text_27313.txt
# /content/working/texts/text_81345.txt
# /content/working/texts/text_68397.txt
# /content/working/texts/text_70768.txt
# /content/working/texts/text_39511.txt
# /content/working/texts/text_17553.txt
# /content/working/texts/text_1380.txt
# /content/working/texts/text_118992.txt
# /content/working/texts/text_87084.txt
# /content/working/texts/text_58322.txt
# /content/working/texts/text_23951.txt
# /content/working/texts/text_79845.txt
# /content/working/texts/text_84048.txt
# /content/working/texts/text_62996.txt
# /content/working/texts/text_25451.txt
# /content/working/texts/text_28078.txt
# /content/working/texts/text_33893.txt
# /content/working/texts/text_105062.txt
# /content/working/texts/text_83974.txt
# /content/working/texts/text_110148.txt
# /content/working/texts/text_66705.txt
# /content/working/texts/text_24263.txt
# /content/working/texts/text_83696.txt
# /content/working/texts/text_58422.txt
# /content/working/texts/text_58762.txt
# /content/working/texts/text_132198.txt
# /content/working/texts/text_45342.txt
# /content/working/texts/text_119647.txt
# /content/working/texts/text_76739.txt
# /content/working/texts/text_118354.txt
# /content/working/texts/text_8054.txt
# /content/working/texts/text_117095.txt
# /content/working/texts/text_21091.txt
# /content/working/texts/text_23101.txt
# /content/working/texts/text_132043.txt
# /content/working/texts/text_60979.txt
# /content/working/texts/text_28944.txt
# /content/working/texts/text_101917.txt
# /content/working/texts/text_85039.txt
# /content/working/texts/text_3346.txt
# /content/working/texts/text_61409.txt
# /content/working/texts/text_123079.txt
# /content/working/texts/text_82466.txt
# /content/working/texts/text_20620.txt
# /content/working/texts/text_11892.txt
# /content/working/texts/text_22651.txt
# /content/working/texts/text_60933.txt
# /content/working/texts/text_40540.txt
# /content/working/texts/text_21817.txt
# /content/working/texts/text_129747.txt
# /content/working/texts/text_83792.txt
# /content/working/texts/text_51820.txt
# /content/working/texts/text_71750.txt
# /content/working/texts/text_120367.txt
# /content/working/texts/text_92581.txt
# /content/working/texts/text_76209.txt
# /content/working/texts/text_95381.txt
# /content/working/texts/text_34392.txt
# /content/working/texts/text_128627.txt
# /content/working/texts/text_10112.txt
# /content/working/texts/text_23978.txt
# /content/working/texts/text_100047.txt
# /content/working/texts/text_100774.txt
# /content/working/texts/text_132051.txt
# /content/working/texts/text_8622.txt
# /content/working/texts/text_16402.txt
# /content/working/texts/text_7638.txt
# /content/working/texts/text_76478.txt
# /content/working/texts/text_113213.txt
# /content/working/texts/text_9930.txt
# /content/working/texts/text_9334.txt
# /content/working/texts/text_103086.txt
# /content/working/texts/text_80233.txt
# /content/working/texts/text_49775.txt
# /content/working/texts/text_44524.txt
# /content/working/texts/text_127965.txt
# /content/working/texts/text_39650.txt
# /content/working/texts/text_7307.txt
# /content/working/texts/text_63363.txt
# /content/working/texts/text_104475.txt
# /content/working/texts/text_57300.txt
# /content/working/texts/text_70053.txt
# /content/working/texts/text_40811.txt
# /content/working/texts/text_69599.txt
# /content/working/texts/text_36442.txt
# /content/working/texts/text_117415.txt
# /content/working/texts/text_15497.txt
# /content/working/texts/text_53379.txt
# /content/working/texts/text_15578.txt
# /content/working/texts/text_80722.txt
# /content/working/texts/text_120519.txt
# /content/working/texts/text_131381.txt
# /content/working/texts/text_5672.txt
# /content/working/texts/text_82350.txt
# /content/working/texts/text_114658.txt
# /content/working/texts/text_98885.txt
# /content/working/texts/text_30518.txt
# /content/working/texts/text_52464.txt
# /content/working/texts/text_40959.txt
# /content/working/texts/text_80012.txt
# /content/working/texts/text_44119.txt
# /content/working/texts/text_75911.txt
# /content/working/texts/text_58441.txt
# /content/working/texts/text_2259.txt
# /content/working/texts/text_114497.txt
# /content/working/texts/text_95092.txt
# /content/working/texts/text_57634.txt
# /content/working/texts/text_100453.txt
# /content/working/texts/text_63107.txt
# /content/working/texts/text_51543.txt
# /content/working/texts/text_92618.txt
# /content/working/texts/text_129032.txt
# /content/working/texts/text_15806.txt
# /content/working/texts/text_16695.txt
# /content/working/texts/text_52003.txt
# /content/working/texts/text_115311.txt
# /content/working/texts/text_93738.txt
# /content/working/texts/text_93018.txt
# /content/working/texts/text_123836.txt
# /content/working/texts/text_2334.txt
# /content/working/texts/text_123899.txt
# /content/working/texts/text_100543.txt
# /content/working/texts/text_81292.txt
# /content/working/texts/text_70841.txt
# /content/working/texts/text_33240.txt
# /content/working/texts/text_29593.txt
# /content/working/texts/text_72103.txt
# /content/working/texts/text_31370.txt
# /content/working/texts/text_18317.txt
# /content/working/texts/text_129752.txt
# /content/working/texts/text_9813.txt
# /content/working/texts/text_25948.txt
# /content/working/texts/text_64460.txt
# /content/working/texts/text_72064.txt
# /content/working/texts/text_55150.txt
# /content/working/texts/text_88560.txt
# /content/working/texts/text_30299.txt
# /content/working/tokenizer/tok_20000_size.vocab
# /content/working/tokenizer/tok_30000_size.model
# /content/working/tokenizer/tok_16000_size.model
# /content/working/tokenizer/tok_8000_size.model
# /content/working/tokenizer/tok_20000_size.model
# /content/working/tokenizer/tok_8000_size.vocab
# /content/working/tokenizer/tok_30000_size.vocab
# /content/working/tokenizer/tok_16000_size.vocab
# /content/sample_data/README.md
# /content/sample_data/anscombe.json
# /content/sample_data/mnist_test.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/california_housing_test.csv

# %% [markdown]
# ## **files saved:vocab and model of all sizes(8000,16000,20000,30000)**

# %% [markdown]
# ## **List of Sentences for Tokenization**

# %%
sentences = [

    'அவர் தினமும் யோகா செய்வார்.',

    'நேற்று மழை பெய்ததால் நான் வீட்டில் இருந்தேன்.',

    'ஒரு பூனை மூக்கு அடைப்பதற்கு இரண்டு இடைவெளிகள்.',

    'சமூக வலைதளங்கள் நவீன தகவல் பரிமாற்றத்துக்கு உதவுகின்றன.',
]

# %%
import sentencepiece as spm
from pathlib import Path
from IPython.core.display import display, HTML
from string import Template

sp = spm.SentencePieceProcessor()

TOK_PATH = '/content/working/tokenizer'

# %% [markdown]
# ## **Tokenizing and Displaying Results in HTML Table**

# %%
from IPython.core.display import display, HTML
from string import Template

MODEL_PATHS = sorted(MODEL_PATHS, key=lambda p: int(p.stem.split('_')[1]))

td_text = Template('<td>$text</td>')
tr_text = Template('<tr><td>$name</td> $li_elem</tr>')

def tokenize_and_display_results(text):
    model_texts = []

    for model in MODEL_PATHS:

        sp.Load(str(model))

        tok = sp.EncodeAsPieces(text)

        word_html = ''.join([td_text.substitute(text=word) for word in tok])
        list_html = tr_text.substitute(name=model.stem, li_elem=word_html)
        model_texts.append(list_html)

    return display(HTML('<table>' + ''.join(model_texts) + '</table>'))

# %%
tokenize_and_display_results(sentences[0])
# Out:
# <table><tr><td>tok_8000_size</td> <td>▁அவர்</td><td>▁தினமும்</td><td>▁யோக</td><td>ா</td><td>▁செய்</td><td>வார்</td><td>.</td></tr><tr><td>tok_16000_size</td> <td>▁அவர்</td><td>▁தினமும்</td><td>▁யோகா</td><td>▁செய்வார்</td><td>.</td></tr><tr><td>tok_20000_size</td> <td>▁அவர்</td><td>▁தினமும்</td><td>▁யோகா</td><td>▁செய்வார்</td><td>.</td></tr><tr><td>tok_30000_size</td> <td>▁அவர்</td><td>▁தினமும்</td><td>▁யோகா</td><td>▁செய்வார்</td><td>.</td></tr></table>

# %%
tokenize_and_display_results(sentences[1])
# Out:
# <table><tr><td>tok_8000_size</td> <td>▁நே</td><td>ற்று</td><td>▁மழை</td><td>▁பெய்</td><td>த</td><td>தால்</td><td>▁நான்</td><td>▁வீட்டில்</td><td>▁இருந்த</td><td>ேன்</td><td>.</td></tr><tr><td>tok_16000_size</td> <td>▁நே</td><td>ற்று</td><td>▁மழை</td><td>▁பெய்</td><td>த</td><td>தால்</td><td>▁நான்</td><td>▁வீட்டில்</td><td>▁இருந்தே</td><td>ன்</td><td>.</td></tr><tr><td>tok_20000_size</td> <td>▁நே</td><td>ற்று</td><td>▁மழை</td><td>▁பெய்</td><td>த</td><td>தால்</td><td>▁நான்</td><td>▁வீட்டில்</td><td>▁இருந்தே</td><td>ன்</td><td>.</td></tr><tr><td>tok_30000_size</td> <td>▁நே</td><td>ற்று</td><td>▁மழை</td><td>▁பெய்த</td><td>தால்</td><td>▁நான்</td><td>▁வீட்டில்</td><td>▁இருந்தே</td><td>ன்</td><td>.</td></tr></table>

# %% [markdown]
# 8000:
#
# More fragmented tokens, less efficient.
#
# Example: ▁பெய் + த → Split into two tokens.
#
# 16000 and 20000:
#
# Slightly larger subwords, but still fragmented.
#
# Example: ▁பெய் + த → Not fully merged.
#
# 30000:
#
# Most compact representation.
#
# Example: ▁பெய்த → Merged into a single token.

# %%
tokenize_and_display_results(sentences[2])
# Out:
# <table><tr><td>tok_8000_size</td> <td>▁ஒரு</td><td>▁பூ</td><td>னை</td><td>▁மூ</td><td>க்கு</td><td>▁அடை</td><td>ப்பதற்கு</td><td>▁இரண்டு</td><td>▁இடைவெளி</td><td>கள்</td><td>.</td></tr><tr><td>tok_16000_size</td> <td>▁ஒரு</td><td>▁பூனை</td><td>▁மூக்கு</td><td>▁அடை</td><td>ப்பதற்கு</td><td>▁இரண்டு</td><td>▁இடைவெளி</td><td>கள்</td><td>.</td></tr><tr><td>tok_20000_size</td> <td>▁ஒரு</td><td>▁பூனை</td><td>▁மூக்கு</td><td>▁அடை</td><td>ப்பதற்கு</td><td>▁இரண்டு</td><td>▁இடைவெளி</td><td>கள்</td><td>.</td></tr><tr><td>tok_30000_size</td> <td>▁ஒரு</td><td>▁பூனை</td><td>▁மூக்கு</td><td>▁அடை</td><td>ப்பதற்கு</td><td>▁இரண்டு</td><td>▁இடைவெளி</td><td>கள்</td><td>.</td></tr></table>

# %% [markdown]
# 8000:
#
# More fragmented tokens, less efficient.
#
# Example: ▁பூ + னை → Split into two tokens.
#
# 16000, 20000, 30000:
#
# More compact and consistent tokenization.
#
# Example: ▁பூனை → Merged into a single token.
#
# Minimal difference between 20000 and 30000.

# %%
tokenize_and_display_results(sentences[3])
# Out:
# <table><tr><td>tok_8000_size</td> <td>▁சமூக</td><td>▁வலை</td><td>தள</td><td>ங்கள்</td><td>▁நவீன</td><td>▁தகவல்</td><td>▁பரிமாற்ற</td><td>த்துக்கு</td><td>▁உதவ</td><td>ுகின்றன</td><td>.</td></tr><tr><td>tok_16000_size</td> <td>▁சமூக</td><td>▁வலை</td><td>தள</td><td>ங்கள்</td><td>▁நவீன</td><td>▁தகவல்</td><td>▁பரிமாற்ற</td><td>த்துக்கு</td><td>▁உதவுகின்றன</td><td>.</td></tr><tr><td>tok_20000_size</td> <td>▁சமூக</td><td>▁வலைதள</td><td>ங்கள்</td><td>▁நவீன</td><td>▁தகவல்</td><td>▁பரிமாற்ற</td><td>த்துக்கு</td><td>▁உதவுகின்றன</td><td>.</td></tr><tr><td>tok_30000_size</td> <td>▁சமூக</td><td>▁வலைதள</td><td>ங்கள்</td><td>▁நவீன</td><td>▁தகவல்</td><td>▁பரிமாற்ற</td><td>த்துக்கு</td><td>▁உதவுகின்றன</td><td>.</td></tr></table>

# %% [markdown]
# 8000:
#
# More fragmented tokens, less efficient.
#
# Example: ▁வலை + தள + ங்கள்.
#
# 16000:
#
# Slightly larger subword units.
#
# Example: ▁உதவ + ுகின்றன.
#
# 20000:
#
# More compact tokens, better efficiency.
#
# Example: ▁வலைதள + ங்கள்.
#
# 30000:
#
# Most compact representation, minimal fragmentation.
#
# Best for low-resource languages.

# %% [markdown]
# ---
#
# RESULT:
# 8000: More fragmented, less efficient.
#
# 16000 & 20000: Moderate efficiency, slight fragmentation.
#
# 30000: Most compact and efficient, ideal for Tamil NLP.
#
# Best choice: 30000 for better tokenization and model performance.

# %% [markdown]
# ## **Why Sentence piece tokenization instead of normal tokenization?:comparison**

# %%
import sentencepiece as spm
import re

def standard_tokenizer(text):
    tokens = re.findall(r'\w+|[^\w\s]', text)
    return tokens


sp = spm.SentencePieceProcessor()
model_path = '/content/working/tokenizer/tok_30000_size.model'
sp.Load(model_path)

def sentencepiece_tokenizer(text):
    return sp.EncodeAsPieces(text)

for sentence in sentences:
    std_tokens = standard_tokenizer(sentence)
    sp_tokens = sentencepiece_tokenizer(sentence)

    print(f"\n Original: {sentence}")
    print(f" Standard Tokenization: {std_tokens}")
    print(f" SentencePiece Tokenization: {sp_tokens}")
# Out:
#  Original: அவர் தினமும் யோகா செய்வார்.
#  Standard Tokenization: ['அவர', '்', 'த', 'ி', 'னம', 'ு', 'ம', '்', 'ய', 'ோ', 'க', 'ா', 'ச', 'ெ', 'ய', '்', 'வ', 'ா', 'ர', '்', '.']
#  SentencePiece Tokenization: ['▁அவர்', '▁தினமும்', '▁யோகா', '▁செய்வார்', '.']
#
#  Original: நேற்று மழை பெய்ததால் நான் வீட்டில் இருந்தேன்.
#  Standard Tokenization: ['ந', 'ே', 'ற', '்', 'ற', 'ு', 'மழ', 'ை', 'ப', 'ெ', 'ய', '்', 'தத', 'ா', 'ல', '்', 'ந', 'ா', 'ன', '்', 'வ', 'ீ', 'ட', '்', 'ட', 'ி', 'ல', '்', 'இர', 'ு', 'ந', '்', 'த', 'ே', 'ன', '்', '.']
#  SentencePiece Tokenization: ['▁நே', 'ற்று', '▁மழை', '▁பெய்த', 'தால்', '▁நான்', '▁வீட்டில்', '▁இருந்தே', 'ன்', '.']
#
#  Original: ஒரு பூனை மூக்கு அடைப்பதற்கு இரண்டு இடைவெளிகள்.
#  Standard Tokenization: ['ஒர', 'ு', 'ப', 'ூ', 'ன', 'ை', 'ம', 'ூ', 'க', '்', 'க', 'ு', 'அட', 'ை', 'ப', '்', 'பதற', '்', 'க', 'ு', 'இரண', '்', 'ட', 'ு', 'இட', 'ை', 'வ', 'ெ', 'ள', 'ி', 'கள', '்', '.']
#  SentencePiece Tokenization: ['▁ஒரு', '▁பூனை', '▁மூக்கு', '▁அடை', 'ப்பதற்கு', '▁இரண்டு', '▁இடைவெளி', 'கள்', '.']
#
#  Original: சமூக வலைதளங்கள் நவீன தகவல் பரிமாற்றத்துக்கு உதவுகின்றன.
#  Standard Tokenization: ['சம', 'ூ', 'க', 'வல', 'ை', 'தளங', '்', 'கள', '்', 'நவ', 'ீ', 'ன', 'தகவல', '்', 'பர', 'ி', 'ம', 'ா', 'ற', '்', 'றத', '்', 'த', 'ு', 'க', '்', 'க', 'ு', 'உதவ', 'ு', 'க', 'ி', 'ன', '்', 'றன', '.']
#  SentencePiece Tokenization: ['▁சமூக', '▁வலைதள', 'ங்கள்', '▁நவீன', '▁தகவல்', '▁பரிமாற்ற', 'த்துக்கு', '▁உதவுகின்றன', '.']

# %% [markdown]
# *  Standard Tokenization: Splits words into individual characters or morphemes.
# *  SentencePiece: Retains subword units for meaningful chunks.
#
# Example:
# அவர் →
#
# Standard: ['அவர', '்']
#
# SentencePiece: ['▁அவர்']

# %% [markdown]
# *   Standard Tokenization:Generates more tokens, resulting in longer sequences.
# *  SentencePiece:Produces fewer tokens, making it more efficient.
#
#
# Example:
#
# நேற்று மழை பெய்ததால் நான் வீட்டில் இருந்தேன்.
#
# Standard: 36 tokens
#
# SentencePiece: 9 tokens

# %% [markdown]
# ---
#
#
# # **Conclusion: Why SentencePiece Tokenization?**
# Subword Tokenization:
# Handles rare and OOV words efficiently.
# Creates meaningful subword units.
#
# Language Agnostic:
# Works for Tamil and other low-resource languages.
# No need for pre-segmentation.
#
# Compact Representation:
# Fewer tokens → Better efficiency.
# Improves model performance.
#
# Flexibility:
# Supports multiple model types.
# Easy to customize vocabulary size.
